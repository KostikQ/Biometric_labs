# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
path = r'images/test_1.jpeg'

# %%
image = cv2.imread(path, cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
gray_scale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
print(gray_scale_image)
# Out:
# [[133 133 133 ... 171 171 171]
#  [133 133 133 ... 172 171 171]
#  [133 133 133 ... 172 172 172]
#  ...
#  [133 133 133 ... 160 160 160]
#  [134 133 133 ... 161 161 160]
#  [134 133 133 ... 161 161 161]]

# %%
haarcascade = cv2.CascadeClassifier('cascades/haarcascade_frontalface_default.xml')
faces = haarcascade.detectMultiScale(image, 1.1, 9)
faces
# Out:
# array([[675, 372, 731, 731]])

# %%
for face in faces:
    cv2.rectangle(image, (face[0], face[1]), (face[0] + face[2], face[1] + face[3]), (255, 255, 0), 10)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
\
# Out:
# -1

# %%
# Out:
# False
